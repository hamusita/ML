# %% [markdown]
# <a href="https://colab.research.google.com/github/hamusita/ML/blob/main/ClassificationTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(r"/content/drive/My Drive/Colab Notebooks/play_tennis.csv")

# %%
df
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
fea = ["outlook", "temp", "humidity", "wind"]

# %%
from sklearn.preprocessing import LabelEncoder

label_En = LabelEncoder()
df['outlook']= label_En.fit_transform(df['outlook'])
df['temp']=label_En.fit_transform(df['temp'])
df['humidity']=label_En.fit_transform(df['humidity'])
df['wind']=label_En.fit_transform(df['wind'])
df['play']=label_En.fit_transform(df['play'])

# %%
x, y = df[fea], df["play"]

# %%
from sklearn.model_selection import train_test_split
x_tr, x_te, y_tr, y_te = train_test_split(x, y, train_size=0.8, random_state=0)

# %%
x_tr
# Out:
#     outlook  temp  humidity  wind
# 13        1     2         0     0
# 9         1     2         1     1
# 1         2     1         0     0
# 7         2     2         0     1
# 10        2     2         1     0
# 3         1     2         0     1
# 0         2     1         0     1
# 5         1     0         1     0
# 12        0     1         1     1

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

clf = DecisionTreeClassifier(random_state=10, criterion='entropy')
clf.fit(x_tr, y_tr)
print("train score : {:.3f}".format(clf.score(x_tr, y_tr)))
print("test score : {:.3f}".format(clf.score(x_te, y_te)))
plt.figure(figsize=(30, 15))
plot_tree(clf, filled=True)
plt.show()
# Out:
# train score : 1.000
# test score : 0.333

# %%
["a","b","c"] + "d"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-b6954138e2bd> in <module>()
# ----> 1 ["a","b","c"] + "d"
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(df["play"])
# Out:
# ['No',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No']
